# %%
import unicodecsv as csv    #converts everything into a list of py dictionaries
import pandas as pd
import numpy as np
from datetime import datetime as dt

# %% [markdown]
# # Data Analysis Process

# %% [markdown]
# ### Step 1: Get data

# %% [markdown]
# 1a: Find data

# %% [markdown]
# Categorical Data - Any value that if you ran mathematical operation on it, you'd get nonsensical data

# %% [markdown]
# Ordinal Data - Any value that if you ran mathematical operation on it, you'd get sensical data

# %% [markdown]
# 1b. Pull in data

# %%
engagements_df = pd.read_csv('engagements - engagements.csv')
enrollments_df = pd.read_csv('enrollments - enrollments.csv')
submissions_df = pd.read_csv('submissions - submissions.csv')

# %%
engagements_df
# Out:
#         acct    utc_date  num_courses_visited  total_minutes_visited  \
# 0          0  2018-01-09                    1              11.679374
# 1          0  2018-01-10                    2              37.284887
# 2          0  2018-01-11                    2              53.633746
# 3          0  2018-01-12                    1              33.489270
# 4          0  2018-01-13                    1              64.779678
# ...      ...         ...                  ...                    ...
# 136235  1305  2018-06-14                    0               0.000000
# 136236  1305  2018-06-15                    0               0.000000
# 136237  1305  2018-06-16                    1               2.720136
# 136238  1305  2018-06-17                    0               0.000000
# 136239  1305  2018-06-18                    0               0.000000
#
#         lessons_completed  projects_completed
# 0                       0                   0
# ...

# %%
enrollments_df
# Out:
#       account_key    status   join_date cancel_date  days_to_cancel  \
# 0             700  canceled  2017-11-10  2017-11-16             6.0
# 1             429  canceled  2017-11-10  2018-03-10           120.0
# 2             429  canceled  2018-03-10  2018-06-17            99.0
# 3              60  canceled  2017-11-10  2018-01-14            65.0
# 4              60  canceled  2018-01-14  2018-04-01            77.0
# ...           ...       ...         ...         ...             ...
# 1635          312  canceled  2018-04-01  2018-07-02            92.0
# 1636          312   current  2018-07-08         NaN             NaN
# 1637          818  canceled  2018-01-07  2018-01-12             5.0
# 1638         1069  canceled  2018-06-01  2018-06-01             0.0
# 1639         1101   current  2018-02-25         NaN             NaN
#
#       is_enrolled  is_canceled
# 0           False         True
# 1           False         True
# 2           False         True
# ...

# %%
submissions_df
# Out:
#      creation_date completion_date assigned_rating  account_key  lesson_key  \
# 0       2018-01-14      2018-01-16        UNGRADED          256  3176718735
# 1       2018-01-10      2018-01-13      INCOMPLETE          256  3176718735
# 2       2018-01-20      2018-01-20          PASSED          256  3176718735
# 3       2018-03-10      2018-03-13          PASSED          434  3176718735
# 4       2018-02-17      2018-03-03      INCOMPLETE          434  3176718735
# ...            ...             ...             ...          ...         ...
# 3637    2018-01-13      2018-01-22          PASSED          243  3176718735
# 3638    2018-07-07      2018-07-07      INCOMPLETE          771  3176718735
# 3639    2018-08-16      2018-08-16          PASSED            2  3176718735
# 3640    2018-03-03      2018-03-11          PASSED          623  3176718735
# 3641    2018-07-10      2018-07-11          PASSED         1274  4576183932
#
#      processing_state
# 0           EVALUATED
# ...

# %%
#1. Edit the column name of account_key:

submissions_df.rename(columns={ 'account_key': 'account_number' }, inplace=True)
submissions_df
# Out:
#      creation_date completion_date assigned_rating  account_number  \
# 0       2018-01-14      2018-01-16        UNGRADED             256
# 1       2018-01-10      2018-01-13      INCOMPLETE             256
# 2       2018-01-20      2018-01-20          PASSED             256
# 3       2018-03-10      2018-03-13          PASSED             434
# 4       2018-02-17      2018-03-03      INCOMPLETE             434
# ...            ...             ...             ...             ...
# 3637    2018-01-13      2018-01-22          PASSED             243
# 3638    2018-07-07      2018-07-07      INCOMPLETE             771
# 3639    2018-08-16      2018-08-16          PASSED               2
# 3640    2018-03-03      2018-03-11          PASSED             623
# 3641    2018-07-10      2018-07-11          PASSED            1274
#
#       lesson_key processing_state
# 0     3176718735        EVALUATED
# 1     3176718735        EVALUATED
# 2     3176718735        EVALUATED
# ...

# %%
#2. Pull all null values:
submissions_df.isnull().sum()
# Out:
# creation_date       0
# completion_date     6
# assigned_rating     6
# account_number      0
# lesson_key          0
# processing_state    0
# dtype: int64

# %%
#3. Top 3 accounts with the most minutes visited

engagements_df.nlargest(3, 'total_minutes_visited')
# Out:
#        acct    utc_date  num_courses_visited  total_minutes_visited  \
# 54536   317  2018-07-11                    4            1030.883197
# 56403   328  2018-07-09                    4             945.538914
# 33728   198  2017-12-30                    2             876.512846
#
#        lessons_completed  projects_completed
# 54536                  8                   0
# 56403                  2                   0
# 33728                  1                   0
